# %% [markdown]
# # Sample Notebook
#
# This notebook demonstrates **rendered** review for `.ipynb` files.
#
# - bullet one
# - bullet two

# %%
print("hello from stdout")
21 * 2
# Out:
# hello from stdout
# 42

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero
